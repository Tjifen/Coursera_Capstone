# %% [markdown]
# <h1 align=center><font size = 5>The Battle of Neighborhoods</font></h1>

# %% [markdown]
# <h2 align=center><font size = 4>Finding business target clusters in Boston</font></h2>

# %% [markdown]
# ## Introduction
#
# Finding an appropriate location to launch a business or a location to launch a marketing campaign can be cumbersome. This project seeks to mitigate some of the problems involved in a pre-launch research business process.
#
# I have used a dataset of central Boston venues to locate appropriate cluster locations to launch a business, or launch a marketing campaign. Specifically, I have tried to locate clusters that are absent of chinese businesses to identify areas where a chinese oriented business can be implemented. Likewise, I have tried to locate cluster areas that are dense in chinese venues to identify areas where a chinese marketing campaign could be effective.

# %% [markdown]
# ## Data
#
# The dataset used in the project originates from the Foursquare API service. Venues in and around downtown Boston have been pooled, and then filtered by "chinese" indicators. This process has resulted in numerous locations found in and around downtown Boston.

# %%
import requests
import pandas as pd
import numpy as np
import random

# !pip install geopy
# !pip install folium==0.5.0

from geopy.geocoders import Nominatim
from IPython.display import Image 
from IPython.core.display import HTML 
from pandas.io.json import json_normalize
import folium

import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Requirement already satisfied: folium==0.5.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: branca in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)

# %%
# The code was removed by Watson Studio for sharing.

# %%
address = '24 Beacon St, Boston, MA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 42.35860195 -71.06387508501135

# %%
search_query = 'Chinese'
radius = 5000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=XKVW4LK1JX3ISNNWCSPSVYCNKHN1Z33O1RAWUBWYDWBCZVIM&client_secret=ZXN51UOSVB2SH3V0FCEQRAAQYEGKRXSRMMH4SFXBNOYBJD44&ll=42.35860195,-71.06387508501135&oauth_token=XZ5O3RVL1RI5IRVTZQJGYNF4DC4I4KTWPPFHVTKO34YQTTLR&v=20180604&query=Chinese&radius=5000&limit=1000'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ffca936a59dd21afa024acd'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4bcf2b3d77b29c7466828882',
#     'name': '68 Chinese',
#     'location': {'address': '48 Winter St',
#      'crossStreet': 'Tremont Street',
#      'lat': 42.35590744018555,
#      'lng': -71.06196594238281,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35590744018555,
#        'lng': -71.06196594238281}],
#      'distance': 338,
#      'postalCode': '02108',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['48 Winter St (Tremont Street)',
#       'Boston, MA 02108',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4b783a50f964a520f3bd2ee3',
#     'name': 'Boston Chinese Evangelical Church',
#     'location': {'address': '249 Harrison Ave',
#      'crossStreet': 'Harrison Avenue & Pine Street',
#      'lat': 42.34730970235004,
#      'lng': -71.06323154716769,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.34730970235004,
#        'lng': -71.06323154716769},
#       {'label': 'entrance', 'lat': 42.347216, 'lng': -71.063264}],
#      'distance': 1258,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['249 Harrison Ave (Harrison Avenue & Pine Street)',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '51eff56c498e1fe71b259d44',
#     'name': "Gene's Chinese Flatbread Cafe",
#     'location': {'address': '86 Bedford St',
#      'lat': 42.35333234922326,
#      'lng': -71.05937890340668,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35333234922326,
#        'lng': -71.05937890340668}],
#      'distance': 693,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['86 Bedford St',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '55f41721498e1449d3e8870a',
#     'name': 'Chinese Acupunture & Herb Services',
#     'location': {'address': '320 Washington St.',
#      'lat': 42.35683822631836,
#      'lng': -71.05867767333984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35683822631836,
#        'lng': -71.05867767333984}],
#      'distance': 470,
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['320 Washington St.',
#       'Boston, MA',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3b',
#       'name': 'Acupuncturist',
#       'pluralName': 'Acupuncturists',
#       'shortName': 'Acupuncturist',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4fb51dd7e4b087193af7d10a',
#     'name': 'Chinese food',
#     'location': {'lat': 42.36237928407758,
#      'lng': -71.06454373422586,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.36237928407758,
#        'lng': -71.06454373422586}],
#      'distance': 424,
#      'postalCode': '02114',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Boston, MA 02114', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '51f00006498ec2c34c860ff4',
#     'name': 'Chinese Food Truck',
#     'location': {'lat': 42.36369070063822,
#      'lng': -71.06858286451927,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.36369070063822,
#        'lng': -71.06858286451927}],
#      'distance': 686,
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Boston, MA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4f4357b919834bc91f561d20',
#     'name': 'Chinese Spaghetti Factory',
#     'location': {'address': '73 Essex St',
#      'lat': 42.352403,
#      'lng': -71.060738,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.352403,
#        'lng': -71.060738},
#       {'label': 'entrance', 'lat': 42.352497, 'lng': -71.060443}],
#      'distance': 736,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['73 Essex St', 'Boston, MA 02111', 'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4f32ceca19836c91c7fce7cd',
#     'name': 'The Chinese-American Fine Art Society',
#     'location': {'address': '11 Edinboro St',
#      'lat': 42.352191,
#      'lng': -71.059602,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.352191,
#        'lng': -71.059602},
#       {'label': 'entrance', 'lat': 42.35208, 'lng': -71.059812}],
#      'distance': 795,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['11 Edinboro St',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4be2030218ab2d7f04b05cb4',
#     'name': 'Chinese Consolidated Benevolent Association',
#     'location': {'address': '90 Tyler St',
#      'lat': 42.348853999999996,
#      'lng': -71.061265,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.348853999999996,
#        'lng': -71.061265}],
#      'distance': 1106,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['90 Tyler St', 'Boston, MA 02111', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4e4c3aa2bd413c4cc667d0ee',
#     'name': 'Chinese Gourmet Express',
#     'location': {'address': '8 Park Plz',
#      'lat': 42.351375579833984,
#      'lng': -71.06874084472656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.351375579833984,
#        'lng': -71.06874084472656}],
#      'distance': 898,
#      'postalCode': '02116',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['8 Park Plz', 'Boston, MA 02116', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '5267026e498e10352cf44021',
#     'name': 'Chinese Food on the go',
#     'location': {'lat': 42.351408,
#      'lng': -71.056097,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.351408,
#        'lng': -71.056097}],
#      'distance': 1025,
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Boston, MA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4d250815903c8cfada90ca25',
#     'name': 'Chinese Institute Of Language & Arts',
#     'location': {'address': '30 Kneeland St',
#      'lat': 42.35077361391871,
#      'lng': -71.06189840996842,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35077361391871,
#        'lng': -71.06189840996842},
#       {'label': 'entrance', 'lat': 42.350807, 'lng': -71.061802}],
#      'distance': 886,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['30 Kneeland St',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '504b9082e4b00c010865e4ce',
#     'name': 'Chinese Progressive Association',
#     'location': {'address': '28 Ash St',
#      'lat': 42.3487821394828,
#      'lng': -71.06324377575962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.3487821394828,
#        'lng': -71.06324377575962},
#       {'label': 'entrance', 'lat': 42.348539, 'lng': -71.062963}],
#      'distance': 1094,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['28 Ash St', 'Boston, MA 02111', 'United States']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4f32c32719836c91c7f7c6c8',
#     'name': 'Chinese Overseas Assoc',
#     'location': {'address': '252 Harrison Ave',
#      'lat': 42.347613,
#      'lng': -71.062492,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.347613,
#        'lng': -71.062492}],
#      'distance': 1228,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['252 Harrison Ave',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06376d81259',
#       'name': 'Nightlife Spot',
#       'pluralName': 'Nightlife Spots',
#       'shortName': 'Nightlife',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4f622ecb7beb5f6a86b004f8',
#     'name': 'Boston Chinese Acupuncture',
#     'location': {'address': '60 State St',
#      'lat': 42.35843292541744,
#      'lng': -71.05540752410889,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35843292541744,
#        'lng': -71.05540752410889}],
#      'distance': 696,
#      'postalCode': '02109',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['60 State St', 'Boston, MA 02109', 'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3b',
#       'name': 'Acupuncturist',
#       'pluralName': 'Acupuncturists',
#       'shortName': 'Acupuncturist',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4ede6fba46907c1b475ed4ac',
#     'name': 'Chinese Church Head Start',
#     'location': {'address': '112 Shawmut Ave',
#      'crossStreet': 'Paul street',
#      'lat': 42.34656524658203,
#      'lng': -71.065673828125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.34656524658203,
#        'lng': -71.065673828125}],
#      'distance': 1348,
#      'postalCode': '02118',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['112 Shawmut Ave (Paul street)',
#       'Boston, MA 02118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4c5611e23e2220a18aa05ba5',
#     'name': 'South Boston Chinese',
#     'location': {'address': 'Broadway',
#      'lat': 42.33640806209789,
#      'lng': -71.04737247230712,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.33640806209789,
#        'lng': -71.04737247230712}],
#      'distance': 2819,
#      'postalCode': '02127',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Broadway', 'Boston, MA 02127', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '58c33ed81d21ba792e6bbb62',
#     'name': '发哥煎饼果子 (Big Brother Chinese Crepes)',
#     'location': {'address': '7 Knapp St',
#      'lat': 42.351192,
#      'lng': -71.061897,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.351192,
#        'lng': -71.061897},
#       {'label': 'entrance', 'lat': 42.351196, 'lng': -71.062082}],
#      'distance': 840,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['7 Knapp St', 'Boston, MA 02111', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4ec5467d2c5b6307e6c1030f',
#     'name': 'Nam Bac Hong Chinese Herbs',
#     'location': {'lat': 42.3509684555236,
#      'lng': -71.06088759051612,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.3509684555236,
#        'lng': -71.06088759051612}],
#      'distance': 884,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Boston, MA 02111', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '5617fcef498e226fb1d95c8c',
#     'name': 'North End Acupuncture & Chinese Herbal Medicine',
#     'location': {'address': '256 Hanover St Ste 2',
#      'lat': 42.36363983154297,
#      'lng': -71.05501556396484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.36363983154297,
#        'lng': -71.05501556396484}],
#      'distance': 919,
#      'postalCode': '02113',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['256 Hanover St Ste 2',
#       'Boston, MA 02113',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3b',
#       'name': 'Acupuncturist',
#       'pluralName': 'Acupuncturists',
#       'shortName': 'Acupuncturist',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '148802506'},
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '5148d185e4b0d24a428c29ba',
#     'name': 'Dr. Kwok Lap Wong Chinese Medicine & Acupuncture',
#     'location': {'address': '200 Lincoln St Ste 302',
#      'lat': 42.35025405883789,
#      'lng': -71.05858612060547,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35025405883789,
#        'lng': -71.05858612060547}],
#      'distance': 1026,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['200 Lincoln St Ste 302',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3b',
#       'name': 'Acupuncturist',
#       'pluralName': 'Acupuncturists',
#       'shortName': 'Acupuncturist',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '51d2e9c1498e1f9bf100bfdf',
#     'name': 'Kwong Kow Chinese School',
#     'location': {'address': '87 Tyler St',
#      'lat': 42.3488215262734,
#      'lng': -71.06199024047073,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.3488215262734,
#        'lng': -71.06199024047073}],
#      'distance': 1099,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['87 Tyler St', 'Boston, MA 02111', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4dbeb6221e72b351cae6efce',
#     'name': 'Chinese Food Truck',
#     'location': {'lat': 42.362664806157866,
#      'lng': -71.09198697926816,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.362664806157866,
#        'lng': -71.09198697926816}],
#      'distance': 2356,
#      'cc': 'US',
#      'city': 'Cambridge',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Cambridge, MA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '56452ac1498e7f7534cc0a45',
#     'name': 'Boston Chinese Evangelical Church',
#     'location': {'address': '120 Shawmut Ave',
#      'lat': 42.345947265625,
#      'lng': -71.06612396240234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.345947265625,
#        'lng': -71.06612396240234}],
#      'distance': 1420,
#      'postalCode': '02118',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['120 Shawmut Ave',
#       'Boston, MA 02118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d131941735',
#       'name': 'Spiritual Center',
#       'pluralName': 'Spiritual Centers',
#       'shortName': 'Spiritual',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4f36fcace4b0f4cfde2857e1',
#     'name': 'Asian Chinese Christian Educational and Social Services',
#     'location': {'address': '244 Harrison Ave',
#      'lat': 42.347613,
#      'lng': -71.062492,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.347613,
#        'lng': -71.062492},
#       {'label': 'entrance', 'lat': 42.34779, 'lng': -71.062541}],
#      'distance': 1228,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['244 Harrison Ave',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '59d0ef8e42d8c211371caa5d',
#     'name': 'Boston Chinese Evangelical Church (Chinatown English Service)',
#     'location': {'address': '885 Washington St',
#      'lat': 42.34767150878906,
#      'lng': -71.06468963623047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.34767150878906,
#        'lng': -71.06468963623047}],
#      'distance': 1218,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['885 Washington St',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '51d9be378bbdb49929a92e21',
#     'name': 'Back Bay Acupuncture and Chinese Herbal Medicine',
#     'location': {'address': '581 Boylston St #304',
#      'crossStreet': 'Dartmouth St.',
#      'lat': 42.35043701596782,
#      'lng': -71.07658624649048,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35043701596782,
#        'lng': -71.07658624649048}],
#      'distance': 1385,
#      'postalCode': '02116',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['581 Boylston St #304 (Dartmouth St.)',
#       'Boston, MA 02116',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3b',
#       'name': 'Acupuncturist',
#       'pluralName': 'Acupuncturists',
#       'shortName': 'Acupuncturist',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '60380462'},
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '503672c4e4b0bb9297dd8e61',
#     'name': 'Delicious Chinese Lunch Box',
#     'location': {'lat': 42.353127116723805,
#      'lng': -71.08098436958751,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.353127116723805,
#        'lng': -71.08098436958751}],
#      'distance': 1533,
#      'postalCode': '02116',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Boston, MA 02116', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4c8c6f3c5e38b1f7b0cb31f9',
#     'name': 'Chinese Restaurant',
#     'location': {'address': '429 W Broadway',
#      'lat': 42.3358205567948,
#      'lng': -71.04543857274666,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.3358205567948,
#        'lng': -71.04543857274666}],
#      'distance': 2955,
#      'postalCode': '02127',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['429 W Broadway',
#       'Boston, MA 02127',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4a566f73f964a5202ab51fe3',
#     'name': 'Chinese Food Truck',
#     'location': {'address': 'Louis Pasteur Avenue',
#      'lat': 42.33536888285712,
#      'lng': -71.10343610739884,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.33536888285712,
#        'lng': -71.10343610739884}],
#      'distance': 4157,
#      'postalCode': '02115',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Louis Pasteur Avenue',
#       'Boston, MA 02115',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '3fd66200f964a52029ec1ee3',
#     'name': 'Hsin Hsin Chinese Restaurant',
#     'location': {'address': '25 Massachusetts Ave',
#      'lat': 42.35059510992953,
#      'lng': -71.08934949599802,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35059510992953,
#        'lng': -71.08934949599802}],
#      'distance': 2277,
#      'postalCode': '02115',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['25 Massachusetts Ave',
#       'Boston, MA 02115',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4cd18f9e7561236a526c32f3',
#     'name': 'Bad Chinese Food Truck',
#     'location': {'address': 'Technology square',
#      'crossStreet': 'Mass Ave',
#      'lat': 42.3627119743952,
#      'lng': -71.09057685135306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.3627119743952,
#        'lng': -71.09057685135306}],
#      'distance': 2243,
#      'cc': 'US',
#      'city': 'Cambridge',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Technology square (Mass Ave)',
#       'Cambridge, MA',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4c3a8a08d94dc9b65f82fee7',
#     'name': 'Chinese Dragon',
#     'location': {'address': '380 Chelsea St',
#      'lat': 42.37923660654362,
#      'lng': -71.02784467772281,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.37923660654362,
#        'lng': -71.02784467772281}],
#      'distance': 3749,
#      'postalCode': '02128',
#      'cc': 'US',
#      'city': 'East Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['380 Chelsea St',
#       'East Boston, MA 02128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '35440',
#      'url': 'https://www.grubhub.com/restaurant/chinese-dragon-380-chelsea-st-east-boston/35440?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=35440',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4f32200d19836c91c7b88162',
#     'name': 'Empire Chinese Restaurant',
#     'location': {'address': '480 Cambridge St',
#      'lat': 42.37137985229492,
#      'lng': -71.0843276977539,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 42.371512,
#        'lng': -71.084284},
#       {'label': 'display',
#        'lat': 42.37137985229492,
#        'lng': -71.0843276977539}],
#      'distance': 2202,
#      'postalCode': '02141',
#      'cc': 'US',
#      'city': 'Cambridge',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['480 Cambridge St',
#       'Cambridge, MA 02141',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4c0682cfcf8c76b092923a65',
#     'name': 'Chinese Kitchen Truck',
#     'location': {'lat': 42.378021,
#      'lng': -71.116409,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.378021,
#        'lng': -71.116409}],
#      'distance': 4831,
#      'postalCode': '02138',
#      'cc': 'US',
#      'city': 'Cambridge',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Cambridge, MA 02138', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '3fd66200f964a52076ec1ee3',
#     'name': 'China Pearl Restaurant',
#     'location': {'address': '9 Tyler St',
#      'crossStreet': 'btwn Beach St. & Kneeland St.',
#      'lat': 42.35111151553748,
#      'lng': -71.06079880778925,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35111151553748,
#        'lng': -71.06079880778925}],
#      'distance': 871,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['9 Tyler St (btwn Beach St. & Kneeland St.)',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4f321bdb19836c91c7b6c0e3',
#     'name': 'Far East Chinese Restaurant',
#     'location': {'address': '183 Massachusetts Ave',
#      'lat': 42.34560012817383,
#      'lng': -71.0872573852539,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.34560012817383,
#        'lng': -71.0872573852539}],
#      'distance': 2407,
#      'postalCode': '02115',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['183 Massachusetts Ave',
#       'Boston, MA 02115',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4f9042b8e4b0926efadd2286',
#     'name': 'Savory Food Truck',
#     'location': {'lat': 42.35179929976585,
#      'lng': -71.06630215361281,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35179929976585,
#        'lng': -71.06630215361281}],
#      'distance': 783,
#      'postalCode': '02116',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Boston, MA 02116', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4396dfeaf964a5209b2b1fe3',
#     'name': "P.F. Chang's",
#     'location': {'address': '8 Park Plz Spc D-6',
#      'lat': 42.3519916,
#      'lng': -71.0671335,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.3519916,
#        'lng': -71.0671335}],
#      'distance': 783,
#      'postalCode': '02116',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['8 Park Plz Spc D-6',
#       'Boston, MA 02116',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '342665',
#      'url': 'https://www.grubhub.com/restaurant/pf-changs-8-park-plaza-boston/342665?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=342665',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4f32991c19836c91c7e76586',
#     'name': 'Mr Chinese Restaurant',
#     'location': {'address': '1746 Washington St',
#      'lat': 42.336421966552734,
#      'lng': -71.07656860351562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.336421966552734,
#        'lng': -71.07656860351562}],
#      'distance': 2680,
#      'postalCode': '02118',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['1746 Washington St',
#       'Boston, MA 02118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '3fd66200f964a5207dec1ee3',
#     'name': 'Empire Garden',
#     'location': {'address': '690 Washington St',
#      'lat': 42.35124253439956,
#      'lng': -71.06241812214772,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35124253439956,
#        'lng': -71.06241812214772}],
#      'distance': 827,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['690 Washington St',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '53ee1e9a498ee376b97145e1',
#     'name': "Zoe's Gourmet Chinese Cuisine",
#     'location': {'address': '296 Beacon St',
#      'lat': 42.38359447167948,
#      'lng': -71.11303786692928,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.38359447167948,
#        'lng': -71.11303786692928}],
#      'distance': 4907,
#      'postalCode': '02143',
#      'cc': 'US',
#      'city': 'Cambridge',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['296 Beacon St',
#       'Cambridge, MA 02143',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '335782',
#      'url': 'https://www.grubhub.com/restaurant/zoes-chinese-cuisine-296-beacon-st-somerville/335782?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=335782',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '556fafed498ee58efd06ee48',
#     'name': 'Yuki Shabu-Chinese Gourmet',
#     'location': {'address': '16 Bow St',
#      'crossStreet': 'Warren Ave',
#      'lat': 42.38055582607979,
#      'lng': -71.09741853717078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.38055582607979,
#        'lng': -71.09741853717078}],
#      'distance': 3685,
#      'postalCode': '02143',
#      'cc': 'US',
#      'city': 'Somerville',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['16 Bow St (Warren Ave)',
#       'Somerville, MA 02143',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '205842205'},
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4d24ab670e998cfa1355263f',
#     'name': 'Beijing & Tokyo',
#     'location': {'address': '3 Cambridge Ctr',
#      'lat': 42.36278533935547,
#      'lng': -71.08660125732422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.36278533935547,
#        'lng': -71.08660125732422}],
#      'distance': 1926,
#      'postalCode': '02142',
#      'cc': 'US',
#      'city': 'Cambridge',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['3 Cambridge Ctr',
#       'Cambridge, MA 02142',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4c045647310fc9b64534c761',
#     'name': 'Sunrise Chinese Food',
#     'location': {'address': '1033 Tremont St',
#      'crossStreet': 'Coventry Street',
#      'lat': 42.336610850727325,
#      'lng': -71.08532478633495,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.336610850727325,
#        'lng': -71.08532478633495}],
#      'distance': 3017,
#      'postalCode': '02120',
#      'cc': 'US',
#      'city': 'Roxbury',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['1033 Tremont St (Coventry Street)',
#       'Roxbury, MA 02120',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '339690',
#      'url': 'https://www.grubhub.com/restaurant/sunrise-chinese-food-1033-tremont-street-roxbury-crossing/339690?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=339690',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4af4e050f964a5202af721e3',
#     'name': 'Pearl Villa Restaurant',
#     'location': {'address': '25 Tyler St',
#      'crossStreet': 'at Kneeland St',
#      'lat': 42.35069,
#      'lng': -71.06101,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.35069,
#        'lng': -71.06101},
#       {'label': 'entrance', 'lat': 42.350644, 'lng': -71.060887}],
#      'distance': 911,
#      'postalCode': '02111',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['25 Tyler St (at Kneeland St)',
#       'Boston, MA 02111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4b4bf245f964a520dbab26e3',
#     'name': 'Brigham Circle Chinese Food',
#     'location': {'address': '728 Huntington Ave',
#      'crossStreet': 'Tremont St',
#      'lat': 42.33392049355517,
#      'lng': -71.10520524971002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.33392049355517,
#        'lng': -71.10520524971002},
#       {'label': 'entrance', 'lat': 42.333774, 'lng': -71.105345}],
#      'distance': 4371,
#      'postalCode': '02115',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['728 Huntington Ave (Tremont St)',
#       'Boston, MA 02115',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '301527',
#      'url': 'https://www.grubhub.com/restaurant/brigham-circle-chinese-food-728-huntington-ave-boston/301527?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=301527',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4e4e5329bd4101d0d7a7c222',
#     'name': '#1 Chinese Food',
#     'location': {'address': '49 Warren St',
#      'lat': 42.329066,
#      'lng': -71.083665,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.329066,
#        'lng': -71.083665},
#       {'label': 'entrance', 'lat': 42.329008, 'lng': -71.083534}],
#      'distance': 3669,
#      'postalCode': '02119',
#      'cc': 'US',
#      'city': 'Boston',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['49 Warren St',
#       'Boston, MA 02119',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '5e3dfaecc3f5a700071b915a',
#     'name': 'Yoi Sushi & Chinese Restaurant',
#     'location': {'lat': 42.380726,
#      'lng': -71.097206,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.380726,
#        'lng': -71.097206}],
#      'distance': 3685,
#      'postalCode': '02143',
#      'cc': 'US',
#      'city': 'Somerville',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['Somerville, MA 02143', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1397940',
#      'url': 'https://www.grubhub.com/restaurant/yoi-sushi--chinese-restaurant-16-bow-st-somerville/1397940?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1397940',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1610393910',
#     'hasPerk': False},
#    {'id': '4f32ac5519836c91c7ee9962',
#     'name': 'Golden House Chinese Restaurant',
#     'location': {'address': '35 Central Ave',
#      'lat': 42.3899,
#      'lng': -71.0342,
#      'labeledLatLngs': [{'label': 'display', 'lat': 42.3899, 'lng': -71.0342}],
#      'distance': 4253,
#      'postalCode': '02150',
#      'cc': 'US',
#      'city': 'Chelsea',
#      'state': 'MA',
#      'country': 'United States',
#      'formattedAddress': ['35 Central Ave',
#       'Chelsea, MA 02150',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1610393910',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
df = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df['categories'] = df.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df.columns = [column.split('.')[-1] for column in df.columns]

df
# Out:
#                                                  name          categories  \
# 0                                          68 Chinese  Chinese Restaurant
# 1                   Boston Chinese Evangelical Church              Church
# 2                       Gene's Chinese Flatbread Cafe  Chinese Restaurant
# 3                  Chinese Acupunture & Herb Services       Acupuncturist
# 4                                        Chinese food  Chinese Restaurant
# 5                                  Chinese Food Truck          Food Truck
# 6                           Chinese Spaghetti Factory                Food
# 7               The Chinese-American Fine Art Society         Art Gallery
# 8         Chinese Consolidated Benevolent Association         Event Space
# 9                             Chinese Gourmet Express  Chinese Restaurant
# 10                             Chinese Food on the go  Chinese Restaurant
# 11               Chinese Institute Of Language & Arts              School
# 12                    Chinese Progressive Association          Non-Profit
# 13                             Chinese Overseas Assoc      Nightlife Spot
# 14                         Boston Chinese Acupuncture       Acupuncturist
# 15                          Chinese Church Head Start              School
# 16                               South Boston Chinese  Chinese Restaurant
# 17                发哥煎饼果子 (Big Brother Chinese Crepes)  Chinese Restaurant
# 18                         Nam Bac Hong Chinese Herbs            Pharmacy
# 19    North End Acupuncture & Chinese Herbal Medicine       Acupuncturist
# 20   Dr. Kwok Lap Wong Chinese Medicine & Acupuncture       Acupuncturist
# 21                           Kwong Kow Chinese School              School
# 22                                 Chinese Food Truck          Food Truck
# 23                  Boston Chinese Evangelical Church    Spiritual Center
# 24  Asian Chinese Christian Educational and Social...              Office
# 25  Boston Chinese Evangelical Church (Chinatown E...              Church
# 26   Back Bay Acupuncture and Chinese Herbal Medicine       Acupuncturist
# 27                        Delicious Chinese Lunch Box          Food Truck
# 28                                 Chinese Restaurant  Chinese Restaurant
# 29                                 Chinese Food Truck          Food Truck
# 30                       Hsin Hsin Chinese Restaurant  Chinese Restaurant
# 31                             Bad Chinese Food Truck          Food Truck
# 32                                     Chinese Dragon  Chinese Restaurant
# 33                          Empire Chinese Restaurant  Chinese Restaurant
# 34                              Chinese Kitchen Truck          Food Truck
# 35                             China Pearl Restaurant  Chinese Restaurant
# 36                        Far East Chinese Restaurant  Chinese Restaurant
# 37                                  Savory Food Truck          Food Truck
# 38                                       P.F. Chang's  Chinese Restaurant
# 39                              Mr Chinese Restaurant  Chinese Restaurant
# 40                                      Empire Garden  Dim Sum Restaurant
# 41                      Zoe's Gourmet Chinese Cuisine  Chinese Restaurant
# 42                         Yuki Shabu-Chinese Gourmet    Asian Restaurant
# 43                                    Beijing & Tokyo    Sushi Restaurant
# 44                               Sunrise Chinese Food  Chinese Restaurant
# 45                             Pearl Villa Restaurant  Chinese Restaurant
# 46                        Brigham Circle Chinese Food  Chinese Restaurant
# 47                                    #1 Chinese Food  Chinese Restaurant
# 48                     Yoi Sushi & Chinese Restaurant  Chinese Restaurant
# 49                    Golden House Chinese Restaurant  Chinese Restaurant
#
#                    address                    crossStreet        lat  \
# 0             48 Winter St                 Tremont Street  42.355907
# 1         249 Harrison Ave  Harrison Avenue & Pine Street  42.347310
# 2            86 Bedford St                            NaN  42.353332
# 3       320 Washington St.                            NaN  42.356838
# 4                      NaN                            NaN  42.362379
# 5                      NaN                            NaN  42.363691
# 6              73 Essex St                            NaN  42.352403
# 7           11 Edinboro St                            NaN  42.352191
# 8              90 Tyler St                            NaN  42.348854
# 9               8 Park Plz                            NaN  42.351376
# 10                     NaN                            NaN  42.351408
# 11          30 Kneeland St                            NaN  42.350774
# 12               28 Ash St                            NaN  42.348782
# 13        252 Harrison Ave                            NaN  42.347613
# 14             60 State St                            NaN  42.358433
# 15         112 Shawmut Ave                    Paul street  42.346565
# 16                Broadway                            NaN  42.336408
# 17              7 Knapp St                            NaN  42.351192
# 18                     NaN                            NaN  42.350968
# 19    256 Hanover St Ste 2                            NaN  42.363640
# 20  200 Lincoln St Ste 302                            NaN  42.350254
# 21             87 Tyler St                            NaN  42.348822
# 22                     NaN                            NaN  42.362665
# 23         120 Shawmut Ave                            NaN  42.345947
# 24        244 Harrison Ave                            NaN  42.347613
# 25       885 Washington St                            NaN  42.347672
# 26    581 Boylston St #304                  Dartmouth St.  42.350437
# 27                     NaN                            NaN  42.353127
# 28          429 W Broadway                            NaN  42.335821
# 29    Louis Pasteur Avenue                            NaN  42.335369
# 30    25 Massachusetts Ave                            NaN  42.350595
# 31       Technology square                       Mass Ave  42.362712
# 32          380 Chelsea St                            NaN  42.379237
# 33        480 Cambridge St                            NaN  42.371380
# 34                     NaN                            NaN  42.378021
# 35              9 Tyler St  btwn Beach St. & Kneeland St.  42.351112
# 36   183 Massachusetts Ave                            NaN  42.345600
# 37                     NaN                            NaN  42.351799
# 38      8 Park Plz Spc D-6                            NaN  42.351992
# 39      1746 Washington St                            NaN  42.336422
# 40       690 Washington St                            NaN  42.351243
# 41           296 Beacon St                            NaN  42.383594
# 42               16 Bow St                     Warren Ave  42.380556
# 43         3 Cambridge Ctr                            NaN  42.362785
# 44         1033 Tremont St                Coventry Street  42.336611
# 45             25 Tyler St                 at Kneeland St  42.350690
# 46      728 Huntington Ave                     Tremont St  42.333920
# 47            49 Warren St                            NaN  42.329066
# 48                     NaN                            NaN  42.380726
# 49          35 Central Ave                            NaN  42.389900
#
#           lng                                     labeledLatLngs  distance  \
# 0  -71.061966  [{'label': 'display', 'lat': 42.35590744018555...       338
# 1  -71.063232  [{'label': 'display', 'lat': 42.34730970235004...      1258
# 2  -71.059379  [{'label': 'display', 'lat': 42.35333234922326...       693
# 3  -71.058678  [{'label': 'display', 'lat': 42.35683822631836...       470
# 4  -71.064544  [{'label': 'display', 'lat': 42.36237928407758...       424
# 5  -71.068583  [{'label': 'display', 'lat': 42.36369070063822...       686
# 6  -71.060738  [{'label': 'display', 'lat': 42.352403, 'lng':...       736
# 7  -71.059602  [{'label': 'display', 'lat': 42.352191, 'lng':...       795
# 8  -71.061265  [{'label': 'display', 'lat': 42.34885399999999...      1106
# 9  -71.068741  [{'label': 'display', 'lat': 42.35137557983398...       898
# 10 -71.056097  [{'label': 'display', 'lat': 42.351408, 'lng':...      1025
# 11 -71.061898  [{'label': 'display', 'lat': 42.35077361391871...       886
# 12 -71.063244  [{'label': 'display', 'lat': 42.3487821394828,...      1094
# 13 -71.062492  [{'label': 'display', 'lat': 42.347613, 'lng':...      1228
# 14 -71.055408  [{'label': 'display', 'lat': 42.35843292541744...       696
# 15 -71.065674  [{'label': 'display', 'lat': 42.34656524658203...      1348
# 16 -71.047372  [{'label': 'display', 'lat': 42.33640806209789...      2819
# 17 -71.061897  [{'label': 'display', 'lat': 42.351192, 'lng':...       840
# 18 -71.060888  [{'label': 'display', 'lat': 42.3509684555236,...       884
# 19 -71.055016  [{'label': 'display', 'lat': 42.36363983154297...       919
# 20 -71.058586  [{'label': 'display', 'lat': 42.35025405883789...      1026
# 21 -71.061990  [{'label': 'display', 'lat': 42.3488215262734,...      1099
# 22 -71.091987  [{'label': 'display', 'lat': 42.36266480615786...      2356
# 23 -71.066124  [{'label': 'display', 'lat': 42.345947265625, ...      1420
# 24 -71.062492  [{'label': 'display', 'lat': 42.347613, 'lng':...      1228
# 25 -71.064690  [{'label': 'display', 'lat': 42.34767150878906...      1218
# 26 -71.076586  [{'label': 'display', 'lat': 42.35043701596782...      1385
# 27 -71.080984  [{'label': 'display', 'lat': 42.35312711672380...      1533
# 28 -71.045439  [{'label': 'display', 'lat': 42.3358205567948,...      2955
# 29 -71.103436  [{'label': 'display', 'lat': 42.33536888285712...      4157
# 30 -71.089349  [{'label': 'display', 'lat': 42.35059510992953...      2277
# 31 -71.090577  [{'label': 'display', 'lat': 42.3627119743952,...      2243
# 32 -71.027845  [{'label': 'display', 'lat': 42.37923660654362...      3749
# 33 -71.084328  [{'label': 'entrance', 'lat': 42.371512, 'lng'...      2202
# 34 -71.116409  [{'label': 'display', 'lat': 42.378021, 'lng':...      4831
# 35 -71.060799  [{'label': 'display', 'lat': 42.35111151553748...       871
# 36 -71.087257  [{'label': 'display', 'lat': 42.34560012817383...      2407
# 37 -71.066302  [{'label': 'display', 'lat': 42.35179929976585...       783
# 38 -71.067133  [{'label': 'display', 'lat': 42.3519916, 'lng'...       783
# 39 -71.076569  [{'label': 'display', 'lat': 42.33642196655273...      2680
# 40 -71.062418  [{'label': 'display', 'lat': 42.35124253439956...       827
# 41 -71.113038  [{'label': 'display', 'lat': 42.38359447167948...      4907
# 42 -71.097419  [{'label': 'display', 'lat': 42.38055582607979...      3685
# 43 -71.086601  [{'label': 'display', 'lat': 42.36278533935547...      1926
# 44 -71.085325  [{'label': 'display', 'lat': 42.33661085072732...      3017
# 45 -71.061010  [{'label': 'display', 'lat': 42.35069, 'lng': ...       911
# 46 -71.105205  [{'label': 'display', 'lat': 42.33392049355517...      4371
# 47 -71.083665  [{'label': 'display', 'lat': 42.329066, 'lng':...      3669
# 48 -71.097206  [{'label': 'display', 'lat': 42.380726, 'lng':...      3685
# 49 -71.034200  [{'label': 'display', 'lat': 42.3899, 'lng': -...      4253
#
#    postalCode  cc         city state        country  \
# 0       02108  US       Boston    MA  United States
# 1       02111  US       Boston    MA  United States
# 2       02111  US       Boston    MA  United States
# 3         NaN  US       Boston    MA  United States
# 4       02114  US       Boston    MA  United States
# 5         NaN  US       Boston    MA  United States
# 6       02111  US       Boston    MA  United States
# 7       02111  US       Boston    MA  United States
# 8       02111  US       Boston    MA  United States
# 9       02116  US       Boston    MA  United States
# 10        NaN  US       Boston    MA  United States
# 11      02111  US       Boston    MA  United States
# 12      02111  US       Boston    MA  United States
# 13      02111  US       Boston    MA  United States
# 14      02109  US       Boston    MA  United States
# 15      02118  US       Boston    MA  United States
# 16      02127  US       Boston    MA  United States
# 17      02111  US       Boston    MA  United States
# 18      02111  US       Boston    MA  United States
# 19      02113  US       Boston    MA  United States
# 20      02111  US       Boston    MA  United States
# 21      02111  US       Boston    MA  United States
# 22        NaN  US    Cambridge    MA  United States
# 23      02118  US       Boston    MA  United States
# 24      02111  US       Boston    MA  United States
# 25      02111  US       Boston    MA  United States
# 26      02116  US       Boston    MA  United States
# 27      02116  US       Boston    MA  United States
# 28      02127  US       Boston    MA  United States
# 29      02115  US       Boston    MA  United States
# 30      02115  US       Boston    MA  United States
# 31        NaN  US    Cambridge    MA  United States
# 32      02128  US  East Boston    MA  United States
# 33      02141  US    Cambridge    MA  United States
# 34      02138  US    Cambridge    MA  United States
# 35      02111  US       Boston    MA  United States
# 36      02115  US       Boston    MA  United States
# 37      02116  US       Boston    MA  United States
# 38      02116  US       Boston    MA  United States
# 39      02118  US       Boston    MA  United States
# 40      02111  US       Boston    MA  United States
# 41      02143  US    Cambridge    MA  United States
# 42      02143  US   Somerville    MA  United States
# 43      02142  US    Cambridge    MA  United States
# 44      02120  US      Roxbury    MA  United States
# 45      02111  US       Boston    MA  United States
# 46      02115  US       Boston    MA  United States
# 47      02119  US       Boston    MA  United States
# 48      02143  US   Somerville    MA  United States
# 49      02150  US      Chelsea    MA  United States
#
#                                      formattedAddress  \
# 0   [48 Winter St (Tremont Street), Boston, MA 021...
# 1   [249 Harrison Ave (Harrison Avenue & Pine Stre...
# 2    [86 Bedford St, Boston, MA 02111, United States]
# 3     [320 Washington St., Boston, MA, United States]
# 4                   [Boston, MA 02114, United States]
# 5                         [Boston, MA, United States]
# 6      [73 Essex St, Boston, MA 02111, United States]
# 7   [11 Edinboro St, Boston, MA 02111, United States]
# 8      [90 Tyler St, Boston, MA 02111, United States]
# 9       [8 Park Plz, Boston, MA 02116, United States]
# 10                        [Boston, MA, United States]
# 11  [30 Kneeland St, Boston, MA 02111, United States]
# 12       [28 Ash St, Boston, MA 02111, United States]
# 13  [252 Harrison Ave, Boston, MA 02111, United St...
# 14     [60 State St, Boston, MA 02109, United States]
# 15  [112 Shawmut Ave (Paul street), Boston, MA 021...
# 16        [Broadway, Boston, MA 02127, United States]
# 17      [7 Knapp St, Boston, MA 02111, United States]
# 18                  [Boston, MA 02111, United States]
# 19  [256 Hanover St Ste 2, Boston, MA 02113, Unite...
# 20  [200 Lincoln St Ste 302, Boston, MA 02111, Uni...
# 21     [87 Tyler St, Boston, MA 02111, United States]
# 22                     [Cambridge, MA, United States]
# 23  [120 Shawmut Ave, Boston, MA 02118, United Sta...
# 24  [244 Harrison Ave, Boston, MA 02111, United St...
# 25  [885 Washington St, Boston, MA 02111, United S...
# 26  [581 Boylston St #304 (Dartmouth St.), Boston,...
# 27                  [Boston, MA 02116, United States]
# 28  [429 W Broadway, Boston, MA 02127, United States]
# 29  [Louis Pasteur Avenue, Boston, MA 02115, Unite...
# 30  [25 Massachusetts Ave, Boston, MA 02115, Unite...
# 31  [Technology square (Mass Ave), Cambridge, MA, ...
# 32  [380 Chelsea St, East Boston, MA 02128, United...
# 33  [480 Cambridge St, Cambridge, MA 02141, United...
# 34               [Cambridge, MA 02138, United States]
# 35  [9 Tyler St (btwn Beach St. & Kneeland St.), B...
# 36  [183 Massachusetts Ave, Boston, MA 02115, Unit...
# 37                  [Boston, MA 02116, United States]
# 38  [8 Park Plz Spc D-6, Boston, MA 02116, United ...
# 39  [1746 Washington St, Boston, MA 02118, United ...
# 40  [690 Washington St, Boston, MA 02111, United S...
# 41  [296 Beacon St, Cambridge, MA 02143, United St...
# 42  [16 Bow St (Warren Ave), Somerville, MA 02143,...
# 43  [3 Cambridge Ctr, Cambridge, MA 02142, United ...
# 44  [1033 Tremont St (Coventry Street), Roxbury, M...
# 45  [25 Tyler St (at Kneeland St), Boston, MA 0211...
# 46  [728 Huntington Ave (Tremont St), Boston, MA 0...
# 47    [49 Warren St, Boston, MA 02119, United States]
# 48              [Somerville, MA 02143, United States]
# 49  [35 Central Ave, Chelsea, MA 02150, United Sta...
#
#                           id
# 0   4bcf2b3d77b29c7466828882
# 1   4b783a50f964a520f3bd2ee3
# 2   51eff56c498e1fe71b259d44
# 3   55f41721498e1449d3e8870a
# 4   4fb51dd7e4b087193af7d10a
# 5   51f00006498ec2c34c860ff4
# 6   4f4357b919834bc91f561d20
# 7   4f32ceca19836c91c7fce7cd
# 8   4be2030218ab2d7f04b05cb4
# 9   4e4c3aa2bd413c4cc667d0ee
# 10  5267026e498e10352cf44021
# 11  4d250815903c8cfada90ca25
# 12  504b9082e4b00c010865e4ce
# 13  4f32c32719836c91c7f7c6c8
# 14  4f622ecb7beb5f6a86b004f8
# 15  4ede6fba46907c1b475ed4ac
# 16  4c5611e23e2220a18aa05ba5
# 17  58c33ed81d21ba792e6bbb62
# 18  4ec5467d2c5b6307e6c1030f
# 19  5617fcef498e226fb1d95c8c
# 20  5148d185e4b0d24a428c29ba
# 21  51d2e9c1498e1f9bf100bfdf
# 22  4dbeb6221e72b351cae6efce
# 23  56452ac1498e7f7534cc0a45
# 24  4f36fcace4b0f4cfde2857e1
# 25  59d0ef8e42d8c211371caa5d
# 26  51d9be378bbdb49929a92e21
# 27  503672c4e4b0bb9297dd8e61
# 28  4c8c6f3c5e38b1f7b0cb31f9
# 29  4a566f73f964a5202ab51fe3
# 30  3fd66200f964a52029ec1ee3
# 31  4cd18f9e7561236a526c32f3
# 32  4c3a8a08d94dc9b65f82fee7
# 33  4f32200d19836c91c7b88162
# 34  4c0682cfcf8c76b092923a65
# 35  3fd66200f964a52076ec1ee3
# 36  4f321bdb19836c91c7b6c0e3
# 37  4f9042b8e4b0926efadd2286
# 38  4396dfeaf964a5209b2b1fe3
# 39  4f32991c19836c91c7e76586
# 40  3fd66200f964a5207dec1ee3
# 41  53ee1e9a498ee376b97145e1
# 42  556fafed498ee58efd06ee48
# 43  4d24ab670e998cfa1355263f
# 44  4c045647310fc9b64534c761
# 45  4af4e050f964a5202af721e3
# 46  4b4bf245f964a520dbab26e3
# 47  4e4e5329bd4101d0d7a7c222
# 48  5e3dfaecc3f5a700071b915a
# 49  4f32ac5519836c91c7ee9962

# %%
map_boston = folium.Map(location=[latitude,longitude],zoom_start=10)

for lat,lng,name,categories in zip(df['lat'],df['lng'],df['name'],df['categories']):
    label = '{}, {}'.format(name, categories)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_boston)
map_boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_6148d99bad0645f79dbb68b94844a29d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6148d99bad0645f79dbb68b94844a29d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6148d99bad0645f79dbb68b94844a29d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_6148d99bad0645f79dbb68b94844a29d%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B42.35860195%2C-71.06387508501135%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20 ...

# %%
k=5
df_clustering = df.drop(['name','categories','address','crossStreet','labeledLatLngs','distance','postalCode','cc','city','state','country','formattedAddress','id'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(df_clustering)
kmeans.labels_
df.insert(0, 'Cluster Labels', kmeans.labels_)

df["Cluster Labels"].value_counts()
# Out:
# 1    31
# 0     7
# 2     6
# 3     4
# 4     2
# Name: Cluster Labels, dtype: int64

# %%
# create clustermap
map_clusters = folium.Map(location=[latitude, longitude],zoom_start=12)

# set color scheme
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers
markers_colors = []
for lat, lng, name, cluster in zip(df['lat'], df['lng'], df['name'], df['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_8b51f9fd5cd3456484d8e20f7d5d7345%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8b51f9fd5cd3456484d8e20f7d5d7345%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8b51f9fd5cd3456484d8e20f7d5d7345%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_8b51f9fd5cd3456484d8e20f7d5d7345%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B42.35860195%2C-71.06387508501135%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20 ...
